# %%
"""

[env]
conda create --name streamlit_spacy_1 python=3.9.7
conda info --envs
source activate streamlit_spacy_1
conda deactivate

[path]
cd /Users/brunoflaven/Documents/03_git/BlogArticlesExamples/streamlit-sweetviz-pandas-profiling-eda-made-easy/tedious_manual_eda/

[file]
python 001_tedious_manual_eda.py

[source]
https://github.com/StephenFordham
https://towardsdatascience.com/exploring-a-data-set-with-simple-pandas-and-plot-visualizations-features-73901ee76c6c


"""

import pandas as pd

# personal configuration
import config_values.values_conf as conf

### 1. VALUES ###
CVS_FILE_PATH = conf.CVS_FILE_PATH


# SIMPLE EXPLORATION
print("\n--- SIMPLE EXPLORATION")

# dataset
DATA_FILE = 'Tennis_World_Number_1s.csv'
df = pd.read_csv(CVS_FILE_PATH)
print(df)

# columns
df.drop('Unnamed: 7', axis=1, inplace=True)
columns = df.columns
# print(columns)

# shape
shape = df.shape
# print(shape)

# non_available
non_available = df.isna().sum()
# print(non_available)

# types
types = df.dtypes
# print(types)

# PLAYING WITH COLUMNS
print("\n--- PLAYING WITH COLUMNS")

# 'Tennis_Player', 'Total_Weeks_at_No_1', 'Maximum_Consectutive_Weeks_at_no_1', 'Years_End_no_1','Careers_Wins_Losses', 'Titles', 'Prize_Money'

# best player with the highest win matches in a career. Careers_Wins_Losses has to be split on -

best_players = df[['Careers_Wins', 'Careers_Losses']
            ] = df.Careers_Wins_Losses.str.split('-', expand=True).astype(float)
best_players = df[['Tennis_Player', 'Careers_Wins_Losses',
            'Careers_Wins', 'Careers_Losses']].head()
print(best_players)
# Out:
# --- SIMPLE EXPLORATION
#                      Tennis_Player  Total_Weeks_at_No_1  \
# Roger Federer                  310                  237
# Pete Sampras                   286                  102
# Ivan Lendl                     270                  157
# Jimmy Connors                  268                  160
# Novak Djokovic                 264                  122
# Rafael Nadal                   196                   56
# John McEnroe                   170                   58
# Bjorn Borg                     109                   46
# Andre Agassi                   101                   52
# Lleyton Hewitt                  80                   75
# Stefan Edberg                   72                   24
# Jim Courier                     58                   27
# Gustavo Kuerten                 43                   30
# Andy Murray                     41                   41
# Ilie Nastase                    40                   40
# Mats Wilander                   20                   20
# Andy Roddick                    13                   13
# Boris Becker                    12                    9
# Marat Safin                      9                    4
# Juan Carlos Ferrero              8                    8
# John Newcombe                    8                    8
# Yevgeny Kafelnikov               6                    6
# Thomas Muster                    6                    5
# Marcelo Rios                     6                    4
# Carlos Moya                      2                    2
# Patrick Rafter                   1                    1
#
#                      Maximum_Consectutive_Weeks_at_no_1 Years_End_no_1  \
# Roger Federer                                         5       1222-265
# Pete Sampras                                          6        762-222
# Ivan Lendl                                            4       1068-242
# Jimmy Connors                                         5       1274-282
# Novak Djokovic                                        5        871-182
# Rafael Nadal                                          4        960-196
# John McEnroe                                          4        881-198
# Bjorn Borg                                            2        644-135
# Andre Agassi                                          1        870-274
# Lleyton Hewitt                                        2        616-262
# Stefan Edberg                                         2        801-270
# Jim Courier                                           1        506-237
# Gustavo Kuerten                                       1        358-195
# Andy Murray                                           1        663-191
# Ilie Nastase                                          1        858-320
# Mats Wilander                                         1        571-222
# Andy Roddick                                          1        612-213
# Boris Becker                                          0        713-214
# Marat Safin                                           0        422-267
# Juan Carlos Ferrero                                   0        479-262
# John Newcombe                                         0        552-198
# Yevgeny Kafelnikov                                    0        609-306
# Thomas Muster                                         0        625-273
# Marcelo Rios                                          0        391-192
# Carlos Moya                                           0        575-319
# Patrick Rafter                                        0        358-191
#
#                      Careers_Wins_Losses     Titles  Prize_Money
# Roger Federer                        102  126266005          NaN
# Pete Sampras                          64   43280489          NaN
# Ivan Lendl                            94   21262417          NaN
# Jimmy Connors                        109    8641040          NaN
# Novak Djokovic                        75  134684000          NaN
# Rafael Nadal                          83  111328858          NaN
# John McEnroe                          77   12552132          NaN
# Bjorn Borg                            64    3655751          NaN
# Andre Agassi                          60   31152975          NaN
# Lleyton Hewitt                        30   20879934          NaN
# Stefan Edberg                         41   20630941          NaN
# Jim Courier                           23   14034132          NaN
# Gustavo Kuerten                       20   14807000          NaN
# Andy Murray                           45   61217017          NaN
# Ilie Nastase                          59    2076761          NaN
# Mats Wilander                         33    7956101          NaN
# Andy Roddick                          32   20640030          NaN
# Boris Becker                          49   25080956          NaN
# Marat Safin                           15   14373291          NaN
# Juan Carlos Ferrero                   16   13998165          NaN
# John Newcombe                         35    1062408          NaN
# Yevgeny Kafelnikov                    26   23883797          NaN
# Thomas Muster                         44   12266977          NaN
# Marcelo Rios                          18    9713771          NaN
# Carlos Moya                           20   13443970          NaN
# Patrick Rafter                        11   11133128          NaN
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [1], in <module>
#      37 print(df)
#      39 # columns
# ---> 40 df.drop('Unnamed: 7', axis=1, inplace=True)
#      41 columns = df.columns
#      42 # print(columns)
#      43
#      44 # shape
#
# File /Volumes/mi_disco/opt/anaconda3/envs/eda_made_easy/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Volumes/mi_disco/opt/anaconda3/envs/eda_made_easy/lib/python3.9/site-packages/pandas/core/frame.py:4956, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4809 def drop(
#    4810     self,
#    (...)
#    4817     errors: str = "raise",
#    4818 ):
#    4819     """
#    4820     Drop specified labels from rows or columns.
#    4821
#    (...)
#    4954             weight  1.0     0.8
#    4955     """
# -> 4956     return super().drop(
#    4957         labels=labels,
#    4958         axis=axis,
#    4959         index=index,
#    4960         columns=columns,
#    4961         level=level,
#    4962         inplace=inplace,
#    4963         errors=errors,
#    4964     )
#
# File /Volumes/mi_disco/opt/anaconda3/envs/eda_made_easy/lib/python3.9/site-packages/pandas/core/generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File /Volumes/mi_disco/opt/anaconda3/envs/eda_made_easy/lib/python3.9/site-packages/pandas/core/generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File /Volumes/mi_disco/opt/anaconda3/envs/eda_made_easy/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Unnamed: 7'] not found in axis"
